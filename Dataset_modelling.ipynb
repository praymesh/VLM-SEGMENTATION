# %% [markdown]
# <a href="https://colab.research.google.com/github/praymesh/VLM-SEGMENTATION/blob/main/Dataset_modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import torch
from torch.utils.data import Dataset
import torchvision.transforms as T
import numpy as np
import os

# %%
dataset/
├── images/
│ ├── train2017/
│ │ ├── 000000000001.jpg
│ │ ├── ...
│ └── val2017/
├── annotations/
│ ├── train2017/
│ │ ├── 000000000001.png ← grayscale mask
│ └── val2017/
├── stuff_classes.txt ← class ID to name (e.g. "0 unlabeled")

# %%
# !wget http://images.cocodataset.org/zips/train2017.zip
# !wget http://images.cocodataset.org/zips/val2017.zip
# !wget http://calvin.inf.ed.ac.uk/wp-content/uploads/data/cocostuffdataset/stuffthingmaps_trainval2017.zip
# Out:
# --2025-06-20 13:22:40--  http://images.cocodataset.org/zips/train2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.167.177, 3.5.25.108, 52.216.216.217, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.167.177|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19336861798 (18G) [application/zip]
# Saving to: ‘train2017.zip’
#
# train2017.zip       100%[===================>]  18.01G  33.5MB/s    in 3m 44s
#
# 2025-06-20 13:26:25 (82.4 MB/s) - ‘train2017.zip’ saved [19336861798/19336861798]
#
# --2025-06-20 13:26:25--  http://images.cocodataset.org/zips/val2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 54.231.160.145, 52.217.162.129, 3.5.9.142, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|54.231.160.145|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 815585330 (778M) [application/zip]
# Saving to: ‘val2017.zip’
#
# ...

# %%
# !mkdr datasets/
# !mkdr datasets/images
# !mkdr datasets/coco-stuff/annotations
# !unzip train2017.zip -d datasets/images/
# !unzip val2017.zip -d datasets/images/
# !unzip stuffthingmaps_trainval2017.zip -d datasets/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: datasets/val2017/000000222235.png
#   inflating: datasets/val2017/000000038678.png
#   inflating: datasets/val2017/000000189698.png
#   inflating: datasets/val2017/000000208363.png
#  extracting: datasets/val2017/000000572956.png
#   inflating: datasets/val2017/000000384513.png
#  extracting: datasets/val2017/000000471893.png
#  extracting: datasets/val2017/000000302536.png
#   inflating: datasets/val2017/000000531036.png
#   inflating: datasets/val2017/000000087038.png
#   inflating: datasets/val2017/000000488736.png
#   inflating: datasets/val2017/000000012120.png
#   inflating: datasets/val2017/000000341196.png
#   inflating: datasets/val2017/000000470779.png
#   inflating: datasets/val2017/000000397303.png
#  extracting: datasets/val2017/000000390301.png
#   inflating: datasets/val2017/000000561465.png
#   inflating: datasets/val2017/000000095862.png
#   inflating: datasets/val2017/000000422706.png
# ...

# %%
! ls datasets
# Out:
# train2017  val2017
